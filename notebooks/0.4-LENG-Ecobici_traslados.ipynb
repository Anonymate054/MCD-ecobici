# %%
import fs

MAIN_DIR = fs.open_fs("../../data/raw/Ecobici viajes")
JSON_DIR = MAIN_DIR.getsyspath("station_information.json")

# %%
import pandas as pd
import json
with open(JSON_DIR, 'r') as file:
    data = json.load(file)
df = pd.DataFrame(data['data']['stations'])
df
# Out:
#     station_id                           external_id  \
# 0            5  3ea89109-d2f3-46eb-9c41-c43742050340
# 1            6  ba78b703-4e5a-44bd-ab2c-1eedc71e11c3
# 2            7  6563d263-2342-46e3-8983-461e68d2d615
# 3            8  ec55e597-c8fc-4e86-bcfe-b0e81a494790
# 4            9  a98c7fac-12ce-4895-923b-6b39f04721ca
# ..         ...                                   ...
# 662        681  d7e7ebcf-c8e1-4706-8ade-a39a02746745
# 663        682  00e1da38-bffd-41e3-96b5-c340e7ff2b2a
# 664        683  c2821ebe-6933-4b30-98cb-1ca3b3f35ec5
# 665        688  886c46bc-d6cc-477e-ad1e-2b980446fba7
# 666        689  4f90cbe8-e841-4614-9274-93b86def30df
#
#                                                   name short_name        lat  \
# 0    CE-407  Prolongación Xochicalco-General Emilia...        407  19.367266
# 1    CE-428  Prolongación Uxmal-Av. Popocatépetl (E...        428  19.363404
# 2    CE-427 Avenida México-Coyoacán-Av. Popocatépet...        427  19.364906
# 3                      CE-443 Bruno Traven-Golondrinas        443  19.359583
# 4                 CE-423 Moras-José María Rico (Eje 8)        423  19.367816
# ..                                                 ...        ...        ...
# 662                           CE-509  Juárez - Venecia        509  19.459686
# 663       CE-533  Av Plan de San Luis - Eulalia Gúzman        533  19.460494
# 664         CE-440  Martin Mendalde - M. López Cotilla        440  19.361792
# 665                                             Sup002     Sup002   0.000000
# 666                                               1123       1123   0.000000
#
#            lon     rental_methods  capacity  electric_bike_surcharge_waiver  \
# 0   -99.158656  [CREDITCARD, KEY]        19                           False
# 1   -99.160395  [CREDITCARD, KEY]        27                           False
# 2   -99.162987  [CREDITCARD, KEY]        19                           False
# 3   -99.162085  [CREDITCARD, KEY]        31                           False
# 4   -99.175269  [CREDITCARD, KEY]        23                           False
# ..         ...                ...       ...                             ...
# 662 -99.181778  [CREDITCARD, KEY]        19                           False
# 663 -99.167270  [CREDITCARD, KEY]        23                           False
# 664 -99.171471  [CREDITCARD, KEY]        27                           False
# 665   0.000000  [CREDITCARD, KEY]         0                           False
# 666   0.000000  [CREDITCARD, KEY]         0                           False
#
#      is_charging  eightd_has_key_dispenser  has_kiosk
# 0          False                     False       True
# 1          False                     False       True
# 2          False                     False       True
# 3          False                     False       True
# 4          False                     False       True
# ..           ...                       ...        ...
# 662        False                     False       True
# 663        False                     False       True
# 664        False                     False       True
# 665        False                     False      False
# 666        False                     False      False
#
# [667 rows x 12 columns]

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=25df4652-e935-424f-95eb-02091fa21a09' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
